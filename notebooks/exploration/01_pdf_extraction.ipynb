# %%
import pdfplumber
import pandas as pd

pdf_path = r"C:\Users\mjbou\governance-framework\data\raw\governance_framework_master.pdf"

with pdfplumber.open(pdf_path) as pdf:
    print(f"Pages: {len(pdf.pages)}")
    print(pdf.pages[0].extract_text()[:500])
# Out:
# Pages: 35
# Governance Framework — Master Document
# Framework architecture, principles, source-level measurement decisions for 25 concepts, future enhancements, and outstanding work.
# Purpose
# This framework provides a structure for assessing governance quality at the national level, oriented to the question of how
# governance affects economic and development outcomes. It is designed to apply across sovereign jurisdictions (target
# population >2 million, excluding effectively closed regimes), supporting cross-co

# %%
with pdfplumber.open(pdf_path) as pdf:
    for i, page in enumerate(pdf.pages):
        print(f"\n--- PAGE {i+1} ---")
        print(page.extract_text())
# Out:
# --- PAGE 1 ---
# Governance Framework — Master Document
# Framework architecture, principles, source-level measurement decisions for 25 concepts, future enhancements, and outstanding work.
# Purpose
# This framework provides a structure for assessing governance quality at the national level, oriented to the question of how
# governance affects economic and development outcomes. It is designed to apply across sovereign jurisdictions (target
# population >2 million, excluding effectively closed regimes), supporting cross-country comparison and analytical
# decomposition of governance into substantively meaningful dimensions. The ultimate use case is investment decisions —
# whether to allocate capital to a country — with this framework providing the governance assessment piece. Sovereign
# credit, macroeconomic vulnerability, and other risk factors live outside this framework in separate modules.
# The framework draws on academic measurement projects (V-Dem, Polity, Quality of Government Institute, others),
# multilateral institutions (World Bank, IMF, OECD), think tanks and NGOs (Freedom House, Bertelsmann, Mo Ibrahim,
# World Justice Project, Transparency International, RSF, CIVICUS, IDEA, Pew), and ratings agency methodologies where
# relevant.
# Framework structure and primary measurement sources
# The framework organises governance into 5 categories containing 26 unique concepts (30 total instances after
# multi-placement of 4 concepts). The table below summarises categorisation alongside the primary and secondary
# measurement sources selected for each concept at the source-level pass. Detailed source-by-source rationale (including
# sources considered but excluded) appears in the per-concept sections.
# Category Concept Primary sources Secondary / supplementary
# 1. Political Political settlement V-Dem power-distribution indicators; FSI (none selected as supplementary tier)
# foundations Factionalized Elites (P1); FSI Group Grievance (S1);
# DPI party fragmentation; Powell-Thyne coups
# Political stability and regime WGI Political Stability; V-Dem regime duration; Polity Durable (cross-check); GTD (currency caveat);
# durability Powell-Thyne coups; UCDP and/or ACLED; GPI; WJP MMP; ICRG/EIU (optional paid)
# Factor 5
# 2. State State capacity V-Dem state authority indicators; FSI Security WB Informal Economy Database; ILO social security
# capacity Apparatus (C1) coverage; Hanson-Sigman state capacity
# Statistical and informational World Bank SPI; Open Data Inventory IMF SDDS subscriptions
# infrastructure*
# Government effectiveness and WGI Government Effectiveness; V-Dem Rigorous and WJP Regulatory Enforcement (borderline); QoG
# admin quality Impartial Public Admin (v2clrspct) Expert Survey impartiality/Weberianism (borderline)
# Service delivery and provision of WB WDI sector indicators; WHO GHO; UNESCO UIS; (none — concept measured directly from
# public goods UNDP HDI sub-indicators; WB Human Capital Index; sector-specific sources)
# FSI Public Services (P2)
# Regulatory quality* WGI Regulatory Quality; WJP Regulatory Heritage Business Freedom; Fraser Regulation area
# Enforcement (Factor 6) (with framing caveats)
# 3. Accountability Legislative and constitutional V-Dem legislative constraint indicators (v2xlg_legcon Polity5 XCONST (with supersession caveat)
# (horizontal) checks* and components); CCP separation-of-powers
# features; IPU Parline
# Judicial independence and V-Dem judicial indicators; WJP Factors 7 and 8; CCP Linzer-Staton latent variable; Henisz POLCON
# quality* judicial independence features
# Accountability Electoral process and V-Dem electoral indicators; FH Electoral Process NELDA; IDEA Voter Turnout (compulsion adjustment
# (vertical) competition sub-component; Electoral Integrity Project (PEI); IDEA needed); Polity electoral indicators; CCP electoral
# EMB Database provisions; DPI
# Political participation beyond V-Dem participation indicators; CIVICUS Monitor IDEA Global State of Democracy Participatory
# voting Engagement subindex
# Civil liberties FH Civil Liberties sub-categories D and G; V-Dem civil Pew GRI and SHI; Political Terror Scale; WB Women
# liberties indicators Business and the Law; US State Dept Human Rights
# Reports (Tier 3)
#
# --- PAGE 2 ---
# Category Concept Primary sources Secondary / supplementary
# Media freedom and pluralism RSF World Press Freedom Index; V-Dem media FH Civil Liberties sub-category D (repetition tracked);
# indicators; CPJ journalist safety data CLD/AIE RTI Rating; UNESCO Journalist Killings
# Observatory; Article 19
# Civil society space and vitality V-Dem CSO indicators; CIVICUS Monitor; FH Civil ICNL Civic Freedom Monitor; ILO CEACR (Tier 3)
# Liberties sub-category E
# Government transparency and V-Dem transparency-relevant indicators; WJP Factor Open Budget Survey (repetition with PFM tracked); TI
# openness 3; CLD/AIE RTI Rating Political Finance Database; Global Data Barometer;
# ODIN
# Statistical and informational (see State capacity row above; same source list
# infrastructure* applies — multi-placed)
# 4. Rule of Legal quality and predictability V-Dem v2cltrnslw; V-Dem v2clacjstm/v2clacjstw; (none selected)
# law V-Dem v2xeg_eqaccess; WJP Factor 4; WJP Factor
# 3; CCP
# Judicial independence and (see Accountability horizontal row above —
# quality* multi-placed)
# Personal security and order UNODC Homicide Statistics; V-Dem physical violence Global Peace Index societal safety and security
# indicators; Political Terror Scale; WJP Factor 5 domain
# Property rights and contract V-Dem property rights indicators; Heritage Property Fraser Legal System and Property Rights area
# enforcement Rights; CCP property provisions; WJP Factor 6 (selective); WIPO IP data
# sub-component 6.5
# Control of corruption V-Dem corruption indicators; Transparency Bayesian Corruption Indicator (currency verification);
# International CPI; WJP Factor 2 UNCAC review content (Tier 3, supplementary)
# Legislative and constitutional (see Accountability horizontal row above —
# checks* multi-placed)
# 5. Economic and Public financial management PEFA (where current); Open Budget Survey IMF Fiscal Transparency Evaluations (coverage
# fiscal governance (PFM) verify); IMF WEO fiscal outcomes (low S/N, low
# weight)
# Macroeconomic policy Romelli CBI Index; Dincer-Eichengreen CB Heritage Monetary Freedom / Fraser Sound Money
# framework quality Transparency; IMF Fiscal Rules Database; IMF (monetary only); EIU Country Risk macro (optional
# AREAER; IMF iMaPP; Reinhart-Rogoff exchange rate paid)
# Regulatory quality* (see State capacity row above — multi-placed)
# Financial sector regulatory and FSAP/BCP/IOSCO/IAIS assessments (where Barth-Caprio-Levine bank regulation survey (2019);
# supervisory quality available); FATF compliance ratings; Basel AML Index IMF FSI outcomes (low weight, low S/N)
# State-owned enterprise DEFERRED to v2 — see future enhancements list
# governance
# State control over the economy V-Dem v2clstown (state ownership of economy) IMF GFS Public Corporations data (with definitional
# caveats); OECD PMR State Control (track for future)
# Trade governance WB Logistics Performance Index; OECD Trade WTO Trade Policy Reviews (Tier 3); WTO RTA
# Facilitation Indicators; WTO TFA implementation; KOF database
# Globalisation Index Trade subindex; WB WITS tariff
# data; Heritage Trade Freedom; UNCTAD NTM
# database
# Environmental and climate Yale EPI policy/institutional sub-components; LSE IEA energy data and Policies Database (free
# governance Grantham Climate Laws Database; ND-GAIN portions); BNEF Climatescope; WEF Energy
# governance and readiness; IRENA Renewables Transition Index
# Capacity Statistics; IRENA Renewable Energy
# Policies Database; WB Carbon Pricing Dashboard
# * Concept appears in more than one category. Inventory: 26 unique concepts, 30 instances. WGI Voice and Accountability serves as
# Accountability category roll-up cross-check; WGI Rule of Law as Rule of Law category cross-check.
#
# --- PAGE 3 ---
# Framework architecture and principles
# Architecture
# The framework operates at two structured levels. Categories (5 thematic groupings) provide the top-level reporting and
# communication structure. Concepts (26 unique, 30 instances) sit within categories and represent the substantive
# dimensions of governance that are scored. Within Accountability, concepts are further organised into horizontal
# accountability (government checks on government) and vertical accountability (government accountability to non-state
# actors).
# Below the concept level, sources (datasets and measurement projects) are selected for each concept based on coverage,
# precision, signal quality, and accessibility. Metrics (specific indicators within sources) are selected at the metric-level pass
# that follows source-level decisions.
# Guiding design principles
# Substantive categorisation. Concepts are grouped by what they are about rather than by where they sit in a causal chain
# or what governance is functionally for. This prioritises navigability and matches how governance is taught and discussed.
# Multi-placement where genuinely warranted. A concept is placed in more than one category when it substantively
# serves more than one categorical function — not merely when it relates to other categories. The operational test: direct
# dual-function rather than indirect downstream effect. Four concepts qualify.
# Economic relevance as cross-cutting lens. Each concept carries an annotation of the strength of evidence linking it to
# economic and development outcomes. This informs eventual weighting decisions but is not used to exclude concepts at
# the structural stage.
# Working principles for source and metric selection
# The following principles guide source-level and (eventually) metric-level decisions. They were established iteratively
# through the source-level pass and apply across all concepts.
# 1. Country coverage threshold. Sources should cover the large majority of the framework's country sample (~150–160 countries with
# population >2M, excluding effectively closed regimes). Sources with systematic regional or income-group exclusions are dropped even
# when methodologically strong. Borderline-coverage sources (~135–145) are kept on the table at source level with final inclusion decided
# at metric-level pass against the specific sample.
# 2. Precision-of-fit. Prefer sources that conceptually target the specific concept. Broader aggregate sources can be considered but are
# excluded where precise concept-specific sources exist. Where broad aggregates duplicate content captured directly by underlying
# sources we use, the aggregates serve as category-level cross-checks rather than concept primaries.
# 3. Signal-to-noise consideration. Prefer metrics where cross-country and over-time variation is driven primarily by the governance
# concept rather than by exogenous, cyclical, or confounding factors. Lower-S/N metrics can be supplementary but shouldn't drive scoring.
# Particularly relevant for outcome metrics (e.g., fiscal outcomes have low S/N for PFM because they're heavily driven by commodity
# cycles and external conditions).
# 4. Outcome metrics OK if signal-rich. Don't categorically exclude outcome measures. Evaluate by S/N for the specific concept.
# UNODC homicide is a good outcome measure for personal security (high S/N). Tax-to-GDP is a poor outcome measure for extractive
# capacity (low S/N due to economic structure confound).
# 5. Indicator-level repetition tracked, not prohibited. Where the same indicator legitimately measures content for multiple concepts, it
# can appear in both. The discipline is awareness and documentation, not exclusion. Several indicators appear in multiple concepts (e.g.,
# PTS in Personal Security and Civil Liberties).
# 6. Conceptual chain awareness within categories. Concepts within a category often sit on a causal chain (e.g., State capacity fi
# Government effectiveness and administrative quality fi Service delivery). The same indicators should not measure structural ability,
# current use, and realised outputs simultaneously. Disciplined assignment of indicators to specific points on the chain.
# 7. Tiering reflects both directness and centrality. Source tier-1 vs tier-2 placement reflects (a) quality and directness of measurement
# for the dimension covered, and (b) centrality of that dimension to the concept's role within its category. A direct measure of a peripheral
# sub-dimension is tier 2 even if methodologically strong.
# 8. WGI components as category-level cross-checks. Where the framework uses WGI components' underlying sources directly
# (V-Dem, WJP, FH, etc.), the WGI aggregate is treated as a category-level cross-check at roll-up rather than as a concept primary. Avoids
# double-counting through aggregation.
# 9. Ideologically-loaded sources used selectively. Heritage and Fraser indices have ideological framings of varying intensity across
# components. Components with low loading and broad expert consensus alignment (e.g., Heritage Trade Freedom for openness;
#
# --- PAGE 4 ---
# Heritage Property Rights; Heritage Monetary Freedom) are usable. Components with high loading (Heritage Fiscal Freedom,
# Government Size; Fraser Government Size) are excluded as they conflate policy stance with governance quality.
# 10. Subscription sources require cumulative case. Tier 4 paid sources (EIU at ~$2k/year, ICRG at ~$7k/year, Gallup, MSCI, IISS) are
# kept off the primary list unless the cumulative case across multiple concepts justifies the cost. To date, neither EIU nor ICRG has earned
# primary placement across concepts on precision grounds; the cumulative case for paying is weak.
# Key consolidation decisions
# Four consolidations were made at the framework-design stage to reduce overlap and double-counting that would
# otherwise distort category-level aggregation:
# Internal cohesion absorbed into Political stability. Cohesion is a structural condition; stability is the outcome it most
# directly drives. Cohesion data (FSI Factionalized Elites and Group Grievance, V-Dem group exclusion) feeds in. After
# subsequent refinement, cohesion-related indicators (FSI P1, S1) were placed in Political settlement instead, leaving
# Political stability purely outcome-focused.
# Government effectiveness and Public administration quality merged. Conceptually distinct (current deployment vs.
# standing civil service quality) but available cross-country indicators do not reliably separate them. Merged concept retains
# content from both: V-Dem Rigorous and Impartial Public Administration (v2clrspct) for Weberian/impartiality content; WGI
# Government Effectiveness for policy-implementation effectiveness.
# Constraints on executive power renamed and narrowed. Original scope substantially overlapped with judicial
# independence, electoral process, civil society, media freedom, and rule of law. Renamed Legislative and constitutional
# checks and narrowed to legislative oversight, constitutional architecture, and non-corruption-focused independent
# oversight bodies (central bank, audit institutions, EMBs).
# Rule of law renamed and narrowed. Original scope overlapped with judicial independence, property rights, personal
# security, corruption control, and legislative/constitutional checks. Renamed Legal quality and predictability and narrowed to
# the residual: quality of the law itself, equal treatment in non-judicial contexts, congruence between law and practice, and
# predictability of legal application beyond the courts.
# Multi-placed concepts
# Each placed equally in both categories (no primary/secondary placement):
# (cid:127) Statistical and informational infrastructure: State capacity + Accountability (vertical)
# (cid:127) Legislative and constitutional checks: Accountability (horizontal) + Rule of law
# (cid:127) Judicial independence and quality: Rule of law + Accountability (horizontal)
# (cid:127) Regulatory quality: Economic and fiscal governance + State capacity
#
# --- PAGE 5 ---
# Outstanding work
# To-do list (v1 framework, pending decisions and work)
# Items remaining for v1 framework completion, in approximate order of dependency:
# Consolidated cross-concept source table. Show which sources appear across which concepts. Helps prioritise metric-level pass and
# gives visibility on source overlap and reuse patterns. Will be produced as separate review document.
# Metric-level pass. For each of the 25 concepts, decide on specific indicators within each chosen source. The largest remaining task.
# Requires familiarity with each source's codebook. Borderline-coverage sources to be evaluated against specific country sample at this
# stage.
# EIU vs ICRG subscription decision. Based on cumulative source-level pass: neither has earned primary placement on precision
# grounds. Cumulative case appears weak. Decision to finalise at metric-pass stage but lean is toward not subscribing in v1.
# Track record / predictability / payment culture composite design. Originally deferred. Multiple sourcing options exist: sovereign
# rating action histories, fiscal-rule compliance rates, IMF program completion records, CDS spreads, EMBI sub-components. Decision
# needed on whether to handle as distributed content across existing concepts or as a standalone composite dimension.
# Equality incorporation design. Left as open question when equality was removed as standalone concept. Options: disaggregated
# scoring of existing indicators by group, equality-specific indicators within relevant concepts, or other approach.
# Process/outcome classification of metrics. Original framework principle (process = within state apparatus; outcome = touches
# non-state actors) is established but hasn't been applied concept-by-concept. Address at metric-pass stage.
# Weighting scheme using economic relevance annotations. Per-concept economic relevance annotations (Very strong / Strong /
# Moderate / Thin) exist for concepts 1–9 and need completion for Trade governance and Environmental and climate governance.
# Weighting at category and framework levels uses these annotations.
# Concept 26 (Government transparency and openness) reconsideration. Significant indicator overlap with other concepts (only TI
# Political Finance and Global Data Barometer are unique to it). Decision: keep as own concept (Option A) accepted for now; revisit with
# full framework view before finalising.
# SDG 16 sub-indicators review at metric pass. UN SDG 16 (Peace, Justice, Strong Institutions) contains governance-relevant
# indicators. Most are derived from sources we're already using (UNODC homicide; WGI underlying inputs; TI; etc.), so adding SDG
# directly would mostly create double-counting. At metric pass, review SDG 16.3, 16.5, 16.6, 16.7, 16.10, 16.B indicators to identify any
# with genuinely independent measurement worth incorporating.
# Future enhancements (post-v1)
# Items identified as v1 measurement gaps or quality limitations, to be addressed in subsequent framework iterations. Many
# depend on external data sources expanding coverage or methodology over time.
# (cid:127) SOE governance measurement — OECD SOE Guidelines reviews, iSOEF expansion, OECD Corporate Governance
# Factbook (currently fail coverage); IMF Article IV systematic extraction.
# (cid:127) SOE sector size / state economic control — no good universal-coverage source currently. Concept itself deferred to v2.
# (cid:127) Political settlement direct measurement — possible commissioned country-expert survey along ESID lines for the specific
# sample.
# (cid:127) PFM coverage expansion — depends on PEFA assessment frequency increasing; IMF FTE coverage expansion if it
# occurs.
# (cid:127) Statistical infrastructure data integrity / manipulation measurement — currently a documented gap with no
# standardised cross-country source.
# (cid:127) B-READY rollout tracking — currently ~50 countries, targeting 180. When expanded, strengthens measurement for
# procedural regulatory quality, trade governance, property rights operational efficiency.
# (cid:127) Bureaucratic feature measurement for non-OECD-non-BTI countries — currently QoG Expert Survey is borderline;
# could commission expanded coverage.
# (cid:127) Education quality measurement — PISA/PIRLS/TIMSS fails coverage; better universal learning-outcome measurement
# would strengthen service delivery scoring.
# (cid:127) Multi-source PDF report extraction infrastructure — including IMF Article IVs (macro framework, PFM, SOE governance,
# financial sector content) and WB Country Climate and Development Reports (CCDRs — climate-transition political economy
# content: institutional quality, fiscal sustainability under transition, macro implications, sector exposures, regulatory adaptation).
# CCDR extraction targets political economy and institutional content rather than environmental policy framing specifically. Tier
# 3 extraction infrastructure shared across multiple concepts justifies the operational investment more than per-concept
#
# --- PAGE 6 ---
# extraction would.
# (cid:127) Subscription source evaluation revisit — EIU at $2k or ICRG at $7k, when cumulative case becomes stronger or when
# sources change in their coverage of governance content.
# (cid:127) Custom expert survey approaches — for concepts where third-party measurement is structurally thin (notably political
# settlement).
# (cid:127) CCPI / Climate Action Tracker methodology extension — if methodologies are extended to broader country sample.
# (cid:127) Dedicated environmental institutional capacity measurement — currently a real gap.
# (cid:127) NDC implementation tracking — currently captured only de jure; de facto implementation measurement weak.
# (cid:127) Cross-country extractive capacity measurement — surviving the S/N filter; current proxies (tax/GDP) excluded on noise
# grounds.
# (cid:127) Cross-country audit institution effectiveness measurement — INTOSAI data fragmentary; better measurement needed.
# (cid:127) Cross-country ombudsman institution measurement — weak cross-country measurement currently.
# (cid:127) Internet / digital media freedom universal-coverage measurement — Freedom on the Net fails coverage at ~70
# countries.
# (cid:127) Media ownership concentration cross-country measurement — Media Ownership Monitor covers only ~20 countries.
# (cid:127) Minority rights dimension dedicated measurement — currently captured indirectly through general civil liberties
# measures.
# (cid:127) Cross-country CSO sector size and capacity measurement — Johns Hopkins Nonprofit Sector Project defunct;
# replacement needed.
# (cid:127) Cross-country open data measurement — current sources defunct (Open Data Barometer) or borderline (Global Data
# Barometer).
# (cid:127) Procurement transparency cross-country measurement — sector-specific sources fail coverage.
# (cid:127) Lobbying transparency cross-country measurement — currently very thin globally.
# (cid:127) De facto vs de jure transparency implementation tracking — RTI laws measured; actual disclosure practice less
# measured.
#
# --- PAGE 7 ---
# Per-concept source-level decisions
# The following sections cover all 25 concepts in framework order. Each section provides: conceptual scope; measurement
# challenge specific to the concept; a source-level decision table listing all sources considered with tier assignment and
# rationale; and notes on the state of measurement for the concept.
# Tier conventions: Tier 1 = workhorse primary source; Tier 2 = supporting primary source; Supplementary = useful for
# cross-check or partial coverage at lower weight; Cross-check = used at category roll-up rather than concept score;
# Dropped = excluded with reason.
# Concept 1: Political settlement
# Category: Political foundations
# Scope: the underlying distribution of power among elite factions (horizontal) and between elites and broader social groups (vertical) that
# produces and constrains formal institutions. Captures configuration of power rather than observable institutional features.
# Measurement challenge: probably the hardest of the 25 concepts to measure with third-party quantitative sources. Direct measurement
# in the academic literature uses qualitative case studies and country-expert surveys (ESID, Khan, Kelsall) with limited cross-country
# coverage. Cross-country quantitative work relies on proxies that capture aspects of the underlying construct.
# Source Decision Rationale / notes
# V-Dem power-distribution indicators Primary tier 1 Direct fit for vertical power distribution and horizontal factionalism dimensions. Expert coding,
# (v2pepwrses, v2pepwrsoc, v2x_egal, ~180 countries, annual.
# v2psoppaut, factionalism)
# FSI Factionalized Elites (P1) Primary tier 1 Direct conceptual match for elite fragmentation. 179 countries, annual. Placed here (not in
# Stability) to maintain conceptual separation.
# FSI Group Grievance (S1) Primary tier 1 Captures vertical fragmentation/social cohesion. Same source family as P1. Placed here for
# the same reason.
# DPI (Database of Political Institutions) Primary tier 2 Party fragmentation and government composition as proxies for horizontal elite organisation.
# ~180 countries.
# Powell-Thyne coups Supplementary Revealed measure of settlement instability through realised regime breakdown. Universal,
# 1950–present.
# ESID political settlements typology Dropped — Conceptually most direct match but ~40 developing countries only. Fails coverage threshold.
# coverage Added to future enhancements as candidate for commissioned expert survey.
# BTI stateness component Dropped — ~140 transformation countries; excludes most developed economies.
# coverage
# WGI Political Stability Dropped — Outcome measure of stability, not configuration of settlement. Primary in Political stability
# placement concept instead.
# State of measurement: proxy-based composite from V-Dem and FSI is workable but documents a real limitation: the informal power
# configurations central to political settlements theory aren't fully captured by available third-party sources. Honest framing recommended
# in reporting.
#
# --- PAGE 8 ---
# Concept 2: Political stability and regime durability
# Category: Political foundations
# Scope: durability of the political order, absence of unconstitutional change (coups, revolutions, mass political violence), absence of
# terrorism, low risk of large-scale political violence. Outcome-focused — what actually happens, not configuration of power (which is
# Political settlement).
# Measurement challenge: stability is ambiguous — high stability can reflect either healthy institutions or successful repression. Pairing
# stability with regime quality content (covered in Accountability category) helps interpretation. Backward-looking and forward-looking
# measures are both relevant.
# Source Decision Rationale / notes
# WGI Political Stability and Absence of Primary tier 1 Canonical aggregate stability score. ~215 countries, annual. Aggregator nature creates
# Violence/Terrorism implicit reliance on underlying sources.
# V-Dem regime duration Primary tier 1 Direct measure of regime continuity using V-Dem's own regime classification. Replaces Polity
# Durable as primary on methodological consistency and currency grounds.
# Powell-Thyne coups database Primary tier 1 Direct measure of realised unconstitutional change events. Universal coverage 1950–present.
# UCDP (Uppsala Conflict Data Primary tier 1 Gold-standard academic source for armed conflict; battle deaths, one-sided violence.
# Program) Universal.
# ACLED Primary tier 1 Real-time event data; covers more event types than UCDP (protests, riots, civilian violence).
# ~250 countries/territories. Complement to UCDP.
# Global Peace Index (IEP) Primary tier 2 Composite of 23 indicators; useful as cross-check at concept level. 163 countries, annual.
# WJP Factor 5 (Order and Security) Primary tier 2 Direct fit for stability outcomes. Note: also primary in Personal security and order. 142
# countries borderline.
# Polity Durable Supplementary Classic regime durability measure. Used as cross-check rather than primary due to V-Dem
# supersession and Polity update reliability concerns.
# Global Terrorism Database (START) Supplementary Best historical terrorism source but currency uncertain (funding disruption). Verify status at
# metric pass.
# Mass Mobilization Project Supplementary Protest event data; update status uncertain post-2020.
# PRS ICRG, EIU Country Risk Optional paid Forward-looking risk content adds value but subscription cost is the question. Considered as
# supplementary if cumulative case justifies.
# FSI Factionalized Elites, Group Dropped — Moved to Political settlement to maintain conceptual separation between configuration
# Grievance placement (settlement) and outcomes (stability).
# State of measurement: strong. Multiple methodologically distinct sources cover stability outcomes well. Triangulation across WGI
# aggregate, V-Dem expert coding, and event-based data (UCDP, ACLED, Powell-Thyne) is robust.
#
# --- PAGE 9 ---
# Concept 3: Statistical and informational infrastructure
# Category: State capacity AND Accountability (vertical) — multi-placed
# Scope: capacity, integrity, and accessibility of official statistics. The standing data and information apparatus of the state — statistical
# agency independence and resources, statistical laws and methodology quality, and the actual public availability and timeliness of data.
# Multi-placed because it operates both as a state capability and as accountability infrastructure (citizens, journalists, opposition need data
# to evaluate government).
# Measurement challenge: three distinct sub-dimensions — production capacity, accessibility, and integrity. Production and accessibility
# are well-measured; integrity (resistance to manipulation) has no good standardised cross-country source and is documented as a gap.
# Source Decision Rationale / notes
# World Bank Statistical Performance Primary tier 1 Comprehensive: data infrastructure, sources, products, services, use. 174 countries, annual,
# Indicators (SPI) World Bank API.
# Open Data Inventory (ODIN, Open Primary tier 1 Best-in-class for accessibility/openness sub-dimension. 195 countries, biennial.
# Data Watch) Methodologically distinct from SPI.
# IMF Data Standards subscriptions Primary tier 2 De jure standards compliance signal. Universal but tiered (SDDS Plus for advanced, SDDS
# (SDDS / SDDS Plus / eGDDS) for middle, eGDDS for lower-income).
# V-Dem media corruption / transparent Dropped — Variables initially considered (v2mecorrpt, v2cltrnslw) don't directly measure statistical
# laws indicators precision infrastructure. Stretches that wouldn't pass precision-of-fit. Dropped.
# PARIS21 reports and assessments Dropped — Qualitative country reports; not standardised cross-country dataset. Useful for deep dives
# currency/structure only.
# WGI Government Effectiveness Dropped — Too broad. Aggregates content captured elsewhere.
# precision
# Academic data manipulation work Dropped — currency Specific country cases rather than standardised cross-country index. Real gap; added to
# (Martinez, Wallace, others) / structure future enhancements.
# State of measurement: good for production and accessibility (SPI, ODIN, SDDS). Data integrity / manipulation resistance is a
# documented measurement gap with no honest universal-coverage solution. Best practice: score the concept on production and
# accessibility, note integrity dimension as a known limitation rather than force a loose proxy.
#
# --- PAGE 10 ---
# Concept 4: Government effectiveness and administrative quality
# Category: State capacity
# Scope: the merged concept (former Government Effectiveness + Public Administration Quality). Captures both how well current
# government formulates and implements coherent policy and standing civil service quality (Weberian features: merit recruitment,
# professional norms, security of tenure, impartiality).
# Measurement challenge: heavily measured space, but most indicators are perception-based and correlated. Disciplined selection
# avoids both over-relying on one source and double-counting through WGI's underlying inputs.
# Source Decision Rationale / notes
# WGI Government Effectiveness Primary tier 1 Canonical aggregate. Direct concept fit (GE is literally what it measures). ~215 countries,
# annual, API.
# V-Dem Rigorous and Impartial Public Primary tier 1 Direct fit for PAQ-side content (impartiality of public admin). Expert coding, ~180 countries.
# Administration (v2clrspct)
# WJP Regulatory Enforcement (Factor Borderline — keep Captures administrative-procedure quality. 142 countries (borderline coverage). Also a
# 6) for metric pass candidate for Regulatory Quality concept; need to disambiguate at metric pass.
# QoG Expert Survey impartiality and Borderline — keep Direct fit for Weberian features (closed Weberianism, politicisation, professionalism). ~135
# Weberianism measures for metric pass countries. Coverage borderline against the specific framework sample.
# BTI Steering Capability and Resource Dropped — Methodologically strong but ~140 transformation countries only; excludes developed
# Efficiency coverage economies.
# Mo Ibrahim IIAG Public Administration Dropped — 54 African countries only.
# coverage
# OECD Government at a Glance Dropped — ~40 OECD members plus partners; insufficient for broad sample.
# coverage
# CPIA Public Sector Management Dropped — ~75 IDA-eligible countries only.
# coverage
# Evans-Rauch Weberianness Scale Dropped — Foundational academic measure but 35 countries and not regularly updated.
# currency/coverage
# State of measurement: headline measurement is strong (WGI + V-Dem). PAQ-side content is well-covered by V-Dem but
# supplementary depth from QoG / BTI / OECD GaG is lost on coverage grounds. The framework will be thinner on Weberian features for
# non-OECD-non-BTI countries than ideal; added to future enhancements.
#
# --- PAGE 11 ---
# Concept 5: Service delivery and provision of public goods
# Category: State capacity
# Scope: actual delivery of education, health, infrastructure, social protection, and other public goods to the population. Outcome-focused
# — what citizens receive from the state. Distinct from Government effectiveness (use of capacity) and State capacity (structural ability).
# Measurement challenge: service delivery is unusual among governance concepts in being measured largely through sectoral outcome
# indicators (school enrollment, vaccination coverage, infrastructure access) rather than governance-specific instruments. Disciplined
# source selection avoids the temptation of overly broad composites.
# Source Decision Rationale / notes
# World Bank WDI sector indicators Primary tier 1 Curated indicators on education enrollment/completion, health outcomes, infrastructure
# access. Use specific indicators, not composites. Universal coverage, API access.
# WHO Global Health Observatory Primary tier 1 Health-specific direct outputs: immunisation, mortality, workforce density. Universal coverage,
# API.
# UNESCO Institute for Statistics (UIS) Primary tier 1 Education-specific direct outputs: enrolment, completion, expenditure, teacher-pupil ratios.
# Universal coverage.
# UNDP HDI sub-indicators (life Primary tier 1 Direct outcome indicators. Use sub-indicators, not composite HDI.
# expectancy, schooling years — not
# composite)
# World Bank Human Capital Index Primary tier 2 Synthetic measure: survival, schooling, learning, adult survival. ~170 countries. Useful as
# composite cross-check.
# FSI Public Services (P2) Primary tier 2 Direct composite of basic service provision. 179 countries.
# WGI Government Effectiveness Dropped — Too broad — measures overall governance not service outputs specifically. Primary in
# precision GE+AQ concept; using here too broad.
# Worldwide Bureaucracy Indicators Dropped — Measures public sector employment/wages, not service outputs.
# precision
# Sustainable Development Report Dropped — Composite SDG implementation score; far broader than service delivery (climate, gender,
# (Sachs et al.) precision partnerships).
# PISA, PIRLS, TIMSS Dropped — Quality measurement but mostly OECD + self-selecting participants. Real gap on education
# coverage quality dimension.
# Mo Ibrahim IIAG Human Development Dropped — 54 African countries only.
# coverage
# State of measurement: strong on coverage of services delivered. Weaker on quality dimensions (especially education learning quality
# where universal-coverage assessment fails). Triangulation across WHO, UNESCO, WDI, and FSI provides robust signal.
#
# --- PAGE 12 ---
# Concept 6: Regulatory quality
# Category: Economic and fiscal governance AND State capacity — multi-placed
# Scope: quality of regulation governing private economic activity — well-designed, predictable, proportionate, consistently enforced.
# Multi-placed because it reflects both state capability to design and implement regulation (State capacity) and the regulatory environment
# for economic activity (Economic and fiscal governance).
# Measurement challenge: Doing Business discontinuation (2021) removed a major data source; B-READY is replacement but coverage
# currently inadequate. Procedural quality (RIA, consultation, transparency in rulemaking) has weak universal-coverage measurement.
# Source Decision Rationale / notes
# WGI Regulatory Quality Primary tier 1 Direct concept match. Universal coverage (~215). The aggregate is literally about regulatory
# quality.
# WJP Rule of Law Index — Regulatory Primary tier 1 Direct fit for procedural and enforcement quality. 142 countries (borderline).
# Enforcement (Factor 6)
# Heritage Business Freedom Primary tier 2 Direct fit for regulatory environment as experienced by firms. Ideological framing
# acknowledged but moderate for this dimension.
# Fraser Regulation area Primary tier 2 Similar to Heritage Business Freedom. Same framing caveats.
# World Bank B-READY Track for future Direct fit but ~50 countries currently. Targeting 180. Future enhancement item.
# OECD iREG (Indicators of Regulatory Dropped — ~40 OECD + partners. Strong for procedural quality but fails threshold.
# Policy and Governance) coverage
# PRS ICRG / EIU Operational Risk Dropped — Bundled risk products; regulatory content embedded in broader risk frame.
# precision
# State of measurement: headline regulatory quality is well-measured; procedural quality dimension is weakly measured universally
# (OECD iREG fails coverage). B-READY rollout will eventually help.
#
# --- PAGE 13 ---
# Concept 7: Public financial management (PFM)
# Category: Economic and fiscal governance
# Scope: end-to-end architecture for managing public finances — budget formulation and credibility, policy-based budgeting, predictability
# of execution, procurement systems, public investment management, accounting and reporting, external audit and legislative scrutiny.
# Measurement challenge: one of the thinnest concepts for cross-country governance-precise measurement. Best dedicated source
# (PEFA) has irregular timing per country; OBS has borderline coverage. Countries without recent PEFA or OBS coverage have real
# measurement gaps.
# Source Decision Rationale / notes
# PEFA (Public Expenditure and Primary tier 1 Gold standard PFM assessment across 31 indicators. ~150 countries with at least one
# Financial Accountability) assessment; ~75 with multiples. Tier 3 extraction (PDF reports + Secretariat portal).
# Open Budget Survey (IBP) Primary tier 1 Direct fit for budget transparency and participation. 120 countries (2023 ed.). Biennial. Strong
# methodology.
# IMF Fiscal Transparency Evaluations Keep for metric pass Excellent quality. ~50-60 historically; may have expanded. Confirm current count at metric
# — coverage verify pass.
# IMF WEO fiscal outcomes Supplementary, low Universal coverage. Low S/N for PFM specifically (cyclical, exogenous). Cross-check only at
# weight low weight.
# WGI Government Effectiveness Dropped — Too broad. PFM is one of many things GE captures. Already used in GE+AQ.
# precision
# TADAT, MAPS, DeMPA Dropped — Specific assessment tools; each fails coverage individually. Content embedded in PEFA
# coverage where present.
# CPIA Public Sector Management Dropped — IDA-only.
# coverage
# State of measurement: measurement is genuinely thin and heterogeneous across the sample. Countries with recent PEFA
# assessments will be well-measured; countries with only OBS will be measured on transparency only; countries with neither have real
# gaps. Documented limitation in framework reporting recommended.
#
# --- PAGE 14 ---
# Concept 8: Macroeconomic policy framework quality
# Category: Economic and fiscal governance
# Scope: institutional architecture governing macroeconomic policymaking — fiscal rules and fiscal council design, monetary policy
# framework, central bank independence and credibility, macroprudential institutional setup, exchange rate regime governance. Distinct
# from macroeconomic outcomes.
# Measurement challenge: strong temptation to use macro outcomes (inflation, fiscal balance) as proxies; these have low S/N for
# framework quality given exogenous drivers. Direct institutional measures (CBI indices, fiscal rules databases) are higher S/N and should
# drive scoring.
# Source Decision Rationale / notes
# Romelli (2022) Central Bank Primary tier 1 Current state-of-the-art for CBI. Updates and broadens Cukierman. ~155 countries. Direct fit,
# Independence Index high S/N.
# Dincer-Eichengreen Central Bank Primary tier 1 Complementary CB transparency dimension. ~120 countries. Update status to verify at metric
# Transparency Index pass.
# IMF Fiscal Rules Database (with Primary tier 1 Existence, design, and compliance of fiscal rules. Direct governance measure (not just
# compliance tracking) outcomes).
# IMF AREAER Primary tier 1 Exchange rate regime de jure and de facto. Universal IMF members.
# IMF iMaPP (Integrated Primary tier 1 Macroprudential measure adoption. ~130 countries.
# Macroprudential Policy Database)
# Reinhart-Rogoff exchange rate Primary tier 1 De facto exchange rate regime. Complements AREAER's de jure focus. ~190 countries.
# classifications
# Heritage Monetary Freedom / Fraser Supplementary Monetary stability outcomes — lower ideological loading than other Heritage/Fraser
# Sound Money components on government size/fiscal freedom. Use monetary components only.
# EIU Country Risk Service Optional paid $2k/year. Forward-looking expert assessment. Worth considering if cumulative case across
# (macroeconomic component) concepts justifies.
# Cukierman / GMT central bank Dropped — currency Superseded by Romelli for current data.
# independence /supersession
# EPU index (Baker-Bloom-Davis) Dropped — ~30 countries (mostly developed).
# coverage
# World Uncertainty Index Moved to Better as cross-cutting predictability composite than primary for this concept (broader
# (Ahir-Bloom-Furceri) cross-cutting uncertainty content than macro framework specifically).
# Heritage Fiscal Freedom and Dropped — Higher loading than other Heritage/Fraser components. Conflate policy stance (size of state)
# Government Size / Fraser ideological loading with governance quality.
# Government Size
# IMF WEO macro outcomes (inflation, Supplementary, low Low S/N for framework quality. Cross-check at low weight only.
# fiscal balance, debt) weight if used
# State of measurement: strong. Multiple direct institutional measures across all sub-dimensions (central bank, fiscal framework,
# exchange regime, macroprudential).
#
# --- PAGE 15 ---
# Concept 9: Financial sector regulatory and supervisory quality
# Category: Economic and fiscal governance
# Scope: quality of regulation and supervision of banks, securities markets, insurance, plus the AML/CFT framework. Includes
# legal/regulatory framework (what rules exist) and supervisory effectiveness (whether supervisors have powers, resources,
# independence, and actually use them).
# Measurement challenge: FSAP (gold standard) happens every 5-10 years per country, voluntary for non-systemically-important. FATF
# has better timing but is AML/CFT-specific. Financial outcomes (NPL, capital adequacy) have low S/N for supervisory quality (cyclically
# driven).
# Source Decision Rationale / notes
# IMF/WB FSAP — comprehensive Primary tier 1 Gold standard. Mandatory every 5 years for ~30 systemically important; voluntary for others.
# financial sector assessment ~190 countries with at least one assessment but timing varies. Tier 3 access.
# FATF Mutual Evaluations and Primary tier 1 Direct fit for AML/CFT. ~200 jurisdictions. ~10-year cycle with intermediate follow-ups.
# compliance ratings Structured ratings via fatf-gafi.org (Tier 2 access for ratings, Tier 3 for full reports).
# Basel AML Index (Basel Institute on Primary tier 1 AML/CFT risk composite. ~205 countries, annual, free. Synthesises FATF and other sources
# Governance) — saves extraction labor.
# Basel Core Principles (BCP) Primary tier 1 Banking supervision specifically. Embedded within FSAP.
# assessments
# IOSCO Principles assessments Primary tier 1 Securities regulation specifically. Embedded within FSAP.
# IAIS Insurance Core Principles Primary tier 1 Insurance regulation specifically. Embedded within FSAP.
# assessments
# Barth-Caprio-Levine Bank Regulation Supplementary Direct fit for banking regulation. Most recent comprehensive wave 2019. Currency cap is real.
# and Supervision Survey
# IMF Financial Soundness Indicators Supplementary, low Outcome data (NPL, capital adequacy). Low S/N for supervisory quality specifically. Cyclical.
# (FSI) weight
# FSB jurisdictional implementation Dropped — ~24 FSB jurisdictions only.
# monitoring coverage
# IMF Financial Development Index, Dropped — Measure financial development, not regulation/supervision.
# WB GFDD precision
# WGI Regulatory Quality Dropped — Too broad. Primary in Regulatory quality concept.
# precision
# Heritage Financial Freedom Dropped — Equates lower regulation with more freedom — loaded framing for financial regulation
# ideological loading specifically.
# PRS ICRG Financial Risk Dropped — Bundled with macroeconomic risk; not financial-supervision-specific.
# precision
# State of measurement: strong direct measurement (FSAP, FATF, BCP/IOSCO/IAIS) but Tier 3 access cost is real and coverage timing
# varies. Practical workhorse for AML/CFT is FATF compliance ratings (structured Tier 2). Broader supervisory quality requires FSAP
# extraction work.
#
# --- PAGE 16 ---
# Concept 10: State-owned enterprise governance — DEFERRED TO V2
# Category: Economic and fiscal governance
# Status: deferred to v2 framework. The thinnest concept for cross-country governance-precise measurement in the inventory. The best-fit
# sources fail coverage threshold; broad-coverage alternatives fail precision.
# Decision rationale: best dedicated measurement (OECD SOE Guidelines reviews, OECD Corporate Governance Factbook, iSOEF)
# covers ~50 countries — fails the coverage threshold. PEFA Pillar 3 captures fiscal-risk-from-SOE content where assessments exist
# (~150 countries, timing variable). IMF Article IV staff reports have rich SOE content annually but require Tier 3 extraction. Cross-country
# SOE sector size measurement is also weakly developed (IMF GFS Public Corporations data has definitional inconsistencies and
# coverage gaps; OECD PMR State Control fails coverage).
# Future enhancement path: (1) OECD assessment coverage expansion if it occurs; (2) iSOEF expansion; (3) IMF Article IV systematic
# extraction (also benefits Macro framework, PFM); (4) custom country-by-country research for major SOE economies (China, Russia,
# Gulf, Vietnam, etc.).
# Cross-reference: the size/scope dimension of state economic role is partly captured by the new concept State control over the economy
# (next section). SOE governance quality remains deferred; SOE sector size is now measured.
#
# --- PAGE 17 ---
# Concept 11: State control over the economy
# Category: Economic and fiscal governance
# Scope: the extent and depth of state ownership and direct control of economic activity, including state-owned enterprises, state
# shareholding in private firms, direct economic management functions, and state control of strategic sectors. Distinct from State-owned
# enterprise governance (deferred to v2) — this concept measures the size/scope dimension of state economic role, not the quality of how
# state ownership is managed. Distinct from State capacity — this concept is about scope of state economic activity, not structural state
# capability.
# Conceptual relationship note: State control over the economy and SOE governance (deferred) work together when both are present.
# Size matters for understanding how much of an economy is affected by SOE governance quality; governance quality matters for
# ...
# from Monitor) coverage / currency
# Johns Hopkins Comparative Nonprofit Dropped — currency ~45 countries historically; updates ceased ~2013. CSO sector size measurement is a real
# Sector Project gap.
# WJP Rule of Law Index Dropped — Less direct fit than dedicated civic space sources.
# precision
# BTI Stateness / Political and Social Dropped — Transformation countries only.
# Integration coverage
# EIU Democracy Index Dropped — cost Tier 4 paid.
# State of measurement: strong on civic space dimension. Weaker on CSO vitality (size, capacity, sectoral breadth) — Johns Hopkins
# data defunct, no good universal replacement. Vitality measurement is captured indirectly through V-Dem participatory environment
# indicators. Future enhancement: cross-country CSO sector size and capacity measurement.
#
# --- PAGE 32 ---
# Concept 26: Government transparency and openness
# Category: Accountability (vertical)
# Scope: transparency of government operations and decision-making; openness of government information to citizens; access to
# information (FOI/RTI laws and effective implementation); proactive disclosure; transparency in public procurement, lobbying, party
# finance; open government data initiatives.
# Note: significant indicator overlap with other concepts (only TI Political Finance Database and Global Data Barometer are unique to this
# concept; the rest are also used elsewhere). Whether this concept should be its own concept or absorbed into adjacent concepts is on the
# to-do list for reconsideration.
# Source Decision Rationale / notes
# V-Dem transparency-relevant Primary tier 1 Multiple direct measures. v2cltrnslw also primary in Legal Quality; v2dlconslt also in Political
# indicators (v2cltrnslw, v2dlconslt, Participation. Repetition tracked.
# related)
# WJP Rule of Law Index — Factor 3 Primary tier 1 Direct fit for FOI/RTI/civic participation/complaint mechanisms. Also primary in Legal Quality
# (Open Government) (repetition tracked).
# Centre for Law and Democracy / Primary tier 1 FOI/RTI legislation quality. 138 countries (borderline). Also used in Media Freedom.
# Access Info Europe — RTI Rating
# Open Budget Survey (IBP) Primary tier 2 Budget transparency dimension. Also primary in PFM (repetition tracked).
# Transparency International Political Primary tier 2 Political party and campaign finance transparency. ~180 countries. Unique to this concept.
# Finance Database
# Global Data Barometer Supplementary Open data dimension. 109 countries (borderline). Unique to this concept (successor to Open
# Data Barometer).
# Open Data Inventory (ODIN) Supplementary Primary in Statistical Infrastructure. Useful cross-reference here.
# WGI Voice and Accountability Category-level Used at Accountability category roll-up.
# cross-check
# Open Government Partnership (OGP) Dropped — 75 OGP members only; non-OGP systematically missing.
# — IRM data coverage
# Open Data Barometer (Web Dropped — currency Defunct.
# Foundation)
# Construction Sector Transparency Dropped — ~20 member countries; sector-specific.
# Initiative (CoST) coverage
# EITI (Extractive Industries Dropped — 56 implementing countries; sector-specific.
# Transparency Initiative) coverage
# TI Government Defence Integrity Dropped — 87 countries (borderline); sector-specific.
# Index coverage
# WB Open Data Readiness Dropped — ~50 countries.
# Assessment coverage
# BTI, SGI Dropped — Region or country-type specific.
# coverage
# EIU Democracy Index Dropped — cost Tier 4 paid.
# State of measurement: mixed. Headline transparency (legislative framework, budget transparency) is well-measured. Open government
# / open data dimension is thinner cross-country with currency issues. Sector-specific transparency (procurement, lobbying, defence,
# extractives) has real measurement gaps for non-participating countries. Future enhancements: cross-country open data, procurement
# transparency, lobbying transparency, de facto vs de jure implementation.
#
# --- PAGE 33 ---
# Consolidated cross-concept source map
# This table shows which sources are used across which concepts, separated by tier (primary tier 1, primary tier 2, supplementary, or
# category cross-check). The map helps identify (a) high-reuse sources whose codebook study at metric pass yields disproportionate
# value, (b) overlap patterns where the same indicator legitimately measures multiple concepts, and (c) coverage of the source landscape
# across the framework's 26 concepts.
# Notation: P1 = primary tier 1; P2 = primary tier 2; Sp = supplementary; CC = category cross-check; Tr = track for future; Dr (with reason)
# = considered but dropped.
# Source Used in (concepts & tier)
# V-Dem (multiple variables) Workhorse across nearly all concepts. Variables differ by concept: power-distribution indicators in Political settlement
# (P1); regime duration in Political stability (P1); state authority indicators in State capacity (P1); Rigorous and Impartial
# Public Admin (v2clrspct) in Government effectiveness and admin quality (P1); judicial indicators in Judicial
# independence and quality (P1); physical violence/integrity indicators in Personal security and order (P1); property
# rights indicators in Property rights (P1); corruption indicators in Control of corruption (P1); legislative/executive
# constraint indicators in Legislative and constitutional checks (P1); electoral indicators in Electoral process (P1);
# participation indicators in Political participation beyond voting (P1); civil liberties indicators in Civil liberties (P1);
# media indicators in Media freedom (P1); CSO indicators in Civil society space (P1); transparency-relevant indicators
# (v2cltrnslw, v2dlconslt) in Government transparency (P1) and v2cltrnslw in Legal quality (P1); v2clstown in State
# control over the economy (P1).
# WGI Government Effectiveness Government effectiveness and admin quality (P1). Excluded on precision elsewhere.
# WGI Political Stability Political stability and regime durability (P1).
# WGI Regulatory Quality Regulatory quality (P1).
# WGI Rule of Law Rule of Law category cross-check (CC) — not concept primary anywhere because aggregates content split across
# constituent concepts.
# WGI Control of Corruption Rule of Law category cross-check (CC) — shares underlying sources with CPI; using both for scoring risks
# double-counting.
# WGI Voice and Accountability Accountability category cross-check (CC) across all Accountability concepts.
# WB Worldwide Indicators (WDI) Service delivery (P1) for sector-specific indicators; Trade governance (P1) via WITS tariff data.
# WB Statistical Performance Indicators Statistical and informational infrastructure (P1). Sub-pillars excluded on placement from State capacity.
# (SPI)
# WB Human Capital Index Service delivery (P2).
# WB Informal Economy Database State capacity (P2) as formality proxy for state reach.
# WB Carbon Pricing Dashboard Environmental and climate governance (P1).
# WB Logistics Performance Index (LPI) Trade governance (P1) for trade administration.
# WB Women, Business and the Law Civil liberties (P2) for gender equality dimension.
# IMF Fiscal Rules Database Macroeconomic policy framework quality (P1).
# IMF AREAER Macroeconomic policy framework quality (P1) for exchange regime.
# IMF iMaPP Macroeconomic policy framework quality (P1) for macroprudential framework.
# IMF SDDS subscriptions Statistical and informational infrastructure (P2).
# IMF Fiscal Transparency Evaluations Public financial management (keep for metric pass — coverage verify).
# IMF FSAP + BCP/IOSCO/IAIS Financial sector regulatory and supervisory quality (P1).
# IMF Article IV Future enhancement item (PDF extraction infrastructure). Would benefit Macroeconomic framework, PFM, SOE
# governance, Financial sector.
# IMF GFS Public Corporations State control over the economy (Sp) with definitional caveats.
# IMF WEO macro outcomes PFM (Sp, low weight); Macroeconomic framework (Sp, low weight). Low S/N caveat throughout.
# Fragile States Index (FSI) Different indicators by concept: Factionalized Elites (P1) and Group Grievance (S1) in Political settlement (P1); Public
# Services (P2) in Service delivery (P2); Security Apparatus (C1) in State capacity (P1).
# WJP Rule of Law Index Factors allocated by primary fit: Factor 2 (Absence of Corruption) in Control of corruption (P1); Factor 3 (Open
# Government) in Legal quality (P1) and Government transparency (P1); Factor 4 (Fundamental Rights) in Legal quality
# (P1); Factor 5 (Order and Security) in Personal security (P1) and Political stability (P2); Factor 6 (Regulatory
# Enforcement) in Regulatory quality (P1), sub-component 6.5 in Property rights (P1); Factors 7 (Civil Justice) and 8
# (Criminal Justice) in Judicial independence (P1).
# Freedom House Freedom in the World Disciplined sub-component extraction: Political Rights A (Electoral Process) in Electoral process (P1); Civil Liberties D
# (Freedom of Expression and Belief) in Civil liberties (P1) and Media freedom (P2); Civil Liberties E (Associational and
# Organizational Rights) in Civil society space (P1); Civil Liberties G (Personal Autonomy and Individual Rights) in Civil
# liberties (P1).
# Comparative Constitutions Project De jure constitutional framework reference: Legal quality (P1); Judicial independence (P1); Property rights (P1);
# (CCP) Legislative and constitutional checks (P1); Electoral process (Sp).
# Polity5 Limited use given V-Dem supersession and update concerns: Durable in Political stability (Sp) cross-check; XCONST in
# Legislative and constitutional checks (P2); electoral components in Electoral process (Sp).
#
# --- PAGE 34 ---
# Source Used in (concepts & tier)
# CIVICUS Monitor Political participation beyond voting (P1); Civil society space (P1).
# IDEA EMB Database Electoral process (P1).
# IDEA Global State of Democracy — Political participation beyond voting (P2).
# Participatory Engagement
# IDEA Voter Turnout Database Electoral process (keep for metric pass — compulsion adjustment).
# UNODC Homicide Statistics Personal security and order (P1).
# Political Terror Scale (PTS) Personal security and order (P1); Civil liberties (P2). Indicator repetition tracked.
# Powell-Thyne coup database Political stability (P1); Political settlement (Sp).
# UCDP Political stability (P1).
# ACLED Political stability (P1).
# Global Peace Index Political stability (P2); Personal security (P2).
# Transparency International CPI Control of corruption (P1).
# Bayesian Corruption Indicator Control of corruption (P2).
# TI Political Finance Database Government transparency (P2).
# RSF World Press Freedom Index Media freedom and pluralism (P1).
# CPJ journalist safety data Media freedom and pluralism (P1).
# Centre for Law and Democracy / Access Media freedom (P2); Government transparency (P1).
# Info Europe — RTI Rating
# Romelli CBI Index Macroeconomic policy framework quality (P1).
# Dincer-Eichengreen CB Transparency Macroeconomic policy framework quality (P1).
# Reinhart-Rogoff exchange rate Macroeconomic policy framework quality (P1).
# classifications
# OECD Trade Facilitation Indicators Trade governance (P1).
# WTO TFA implementation tracking Trade governance (P1).
# KOF Globalisation Index — Trade Trade governance (P1).
# subindex
# Heritage Trade Freedom Trade governance (P1).
# UNCTAD NTM database Trade governance (P1).
# Yale Environmental Performance Index Environmental and climate governance (P1).
# — sub-components
# LSE Grantham Climate Laws Database Environmental and climate governance (P1).
# ND-GAIN governance and readiness Environmental and climate governance (P1).
# sub-scores
# IRENA Renewables Capacity Statistics Environmental and climate governance (P1).
# IRENA Renewable Energy Policies Environmental and climate governance (P1).
# Database
# PEFA Public financial management (P1); Pillar 3 considered for SOE governance (concept deferred).
# Open Budget Survey (IBP) Public financial management (P1); Government transparency (P2).
# FATF compliance ratings Financial sector regulatory and supervisory quality (P1).
# Basel AML Index Financial sector regulatory and supervisory quality (P1).
# Barth-Caprio-Levine bank regulation Financial sector regulatory and supervisory quality (Sp).
# survey
# WHO Global Health Observatory Service delivery (P1).
# UNESCO Institute for Statistics Service delivery (P1).
# UNDP HDI sub-indicators Service delivery (P1).
# Heritage Property Rights Property rights and contract enforcement (P1).
# Fraser Legal System and Property Property rights and contract enforcement (P2).
# Rights area (selective)
# WIPO IP data Property rights and contract enforcement (P2).
# ILO social security coverage State capacity (P2).
# Open Data Inventory (ODIN) Statistical and informational infrastructure (P1); Government transparency (Sp).
# Heritage Monetary Freedom / Fraser Macroeconomic policy framework quality (Sp) — monetary components only, lower loading.
# Sound Money
# Heritage Business Freedom; Fraser Regulatory quality (P2) with framing caveats.
# Regulation area
# Hanson-Sigman state capacity index State capacity (Sp) — double-counting caveat (incorporates V-Dem and others).
#
# --- PAGE 35 ---
# Source Used in (concepts & tier)
# Pew Religious Restrictions Index, Social Civil liberties (P2).
# Hostilities Index
# ICNL Civic Freedom Monitor Civil society space (Sp).
# Electoral Integrity Project (PEI) Electoral process (P1).
# NELDA Electoral process (P2).
# IPU Parline Legislative and constitutional checks (P1).
# DPI (Database of Political Institutions) Political settlement (P2); Electoral process (Sp).
# Global Data Barometer Government transparency (Sp).
# Linzer-Staton judicial independence; Judicial independence (Sp) with update frequency caveats.
# Henisz POLCON
# High-reuse sources — priority for codebook study at metric pass
# Sources appearing across many concepts are highest-value targets for detailed codebook study before metric selection, since
# investment in understanding the source yields returns across multiple concepts:
# (cid:127) V-Dem — used across virtually all 26 concepts with different variables per concept. Single highest priority.
# (cid:127) Freedom House Freedom in the World — disciplined sub-component extraction across multiple Accountability concepts.
# Need clarity on which sub-questions feed which concept.
# (cid:127) WJP Rule of Law Index — 8 factors allocated across 6+ concepts. Factor-level allocation needs to be finalised.
# (cid:127) Fragile States Index — different indicators across Political settlement, Service delivery, State capacity.
# (cid:127) Comparative Constitutions Project — de jure framework reference across 5 concepts.
# (cid:127) WGI components — disciplined as primary in 3 concepts (where the concept matches what WGI measures) and category
# cross-check elsewhere. Pattern is settled but worth confirming at metric pass.
# Patterns and observations
# V-Dem dominance. V-Dem is the most heavily used source family in the framework, contributing primary indicators to nearly every
# concept with different variables per concept. The framework's measurement validity depends substantially on V-Dem's data quality.
# Worth investing time in V-Dem codebook study and understanding the V-Dem aggregation methodology.
# Disciplined indicator-level repetition. Several indicators legitimately measure content for multiple concepts (PTS for Personal Security
# and Civil Liberties; RTI Rating for Media Freedom and Government Transparency; OBS for PFM and Government Transparency; Open
# Data Inventory for Statistical Infrastructure and Government Transparency; V-Dem v2cltrnslw for Legal Quality and Government
# Transparency; WJP Factor 5 for Personal Security and Political Stability). All tracked, none prohibited.
# Subscription sources excluded across the framework. EIU, ICRG, Gallup, IISS Military Balance, Sustainalytics/MSCI sovereign
# ESG, Bureau van Dijk are dropped across all concepts on precision-of-fit or cost grounds. Cumulative subscription case is consistently
# weak.
# Sources used as category cross-check rather than concept primary. WGI Rule of Law (Rule of Law category), WGI Control of
# Corruption (Rule of Law category), WGI Voice and Accountability (Accountability category). Used at roll-up rather than concept-score
# level to avoid double-counting through aggregation.
